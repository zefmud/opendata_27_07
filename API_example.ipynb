# %%
import requests
from pprint import pprint

# %%
r = requests.get("https://public-api.nazk.gov.ua/v1/declaration/", params={"q":"Саакашвілі"})
print(r)

# %%
r.json()
# Out:
# {'items': [{'firstname': 'Міхеіл Ніколозович',
#    'id': 'b3f3724a-d1a0-43ca-8d14-906a6c1fbd18',
#    'lastname': 'Саакашвілі',
#    'linkPDF': 'https://public.nazk.gov.ua/storage/documents/pdf/b/3/f/3/b3f3724a-d1a0-43ca-8d14-906a6c1fbd18.pdf',
#    'placeOfWork': 'Голова Одеської обласної державної адміністрації',
#    'position': "державний службовець, посада якого належить до посад державної служби категорії 'а' або 'б'"},
#   {'firstname': 'Міхеіл Ніколозович',
#    'id': '32c9747f-ee45-4209-b0c0-198768d3970c',
#    'lastname': 'Саакашвілі',
#    'linkPDF': 'https://public.nazk.gov.ua/storage/documents/pdf/3/2/c/9/32c9747f-ee45-4209-b0c0-198768d3970c.pdf',
#    'placeOfWork': 'Голова Одеської обласної державної адміністрації',
#    'position': "державний службовець, посада якого належить до посад державної служби категорії 'а' або 'б'"},
#   {'firstname': 'Міхеіл Ніколозович',
#    'id': '691b87de-398f-4e69-ae61-0bbdd753defe',
#    'lastname': 'Саакашвілі',
# ...

# %%
saakashvili_id = "b3f3724a-d1a0-43ca-8d14-906a6c1fbd18"
saakashvili_declaration = requests.get("https://public-api.nazk.gov.ua/v1/declaration/{d_id:s}".format(d_id = saakashvili_id))

# %%
pprint(saakashvili_declaration.json())
# Out:
# {'created_date': '07.04.2017',
#  'data': {'step_0': {'declarationType': '3', 'declarationYear3': '2016'},
#           'step_1': {'actual_apartmentsNum_extendedstatus': '1',
#                      'actual_cityPath': '[Конфіденційна інформація]',
#                      'actual_cityType': '[Конфіденційна інформація]',
#                      'actual_country': '1',
#                      'actual_housePartNum_extendedstatus': '1',
#                      'actual_postCode': '[Конфіденційна інформація]',
#                      'actual_region': '[Конфіденційна інформація]',
#                      'actual_street': '[Конфіденційна інформація]',
#                      'actual_streetType': '[Конфіденційна інформація]',
#                      'actual_streetType_extendedstatus': '1',
#                      'actual_street_extendedstatus': '1',
#                      'apartmentsNum_extendedstatus': '1',
#                      'changedName': False,
# ...
